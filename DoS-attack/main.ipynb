# %%
# %run libs.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3665771 entries, 0 to 3665770
# Data columns (total 12 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       float64
#  1   1       object
#  2   2       int64
#  3   3       object
#  4   4       object
#  5   5       object
#  6   6       object
#  7   7       object
#  8   8       object
#  9   9       object
#  10  10      object
#  11  11      object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 335.6+ MB

# %%
print(X_train)
# Out:
#          3   4   5   6   7   8   9   10
# 3281514  00  00  00  80  00  69  d1  13
# 2897398  24  00  9b  1d  97  02  bd  00
# 2942187  00  20  00  00  00  00  00  00
# 2290793  1b  80  00  ff  1c  80  0f  e0
# 1911552  d8  00  00  8a  00  00  00  00
# ...      ..  ..  ..  ..  ..  ..  ..  ..
# 2374492  00  00  00  00  00  00  00  00
# 3541414  0f  80  00  ff  3a  80  05  d7
# 2246320  00  21  10  ff  00  ff  00  00
# 2790041  00  00  00  80  00  69  d1  13
# 2236254  0b  80  00  ff  f9  7f  04  ce
#
# [2907666 rows x 8 columns]

# %%
type(X_train[3][3281514])
# Out:
# str

# %%
# convert str to byte 
type(X_train[3])
# Out:
# pandas.core.series.Series

# %%
import numpy

# khai bao mot series moi
series = pd.Series([],dtype=numpy.dtype(bytes))

# %%
import sys 

for j in X_train[3]:
    b = bytes(j, 'utf-8')   
    series_b = pd.Series([b])
    series = pd.concat([series, series_b])

# %%
len(X_train[3])
